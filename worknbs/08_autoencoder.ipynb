# %% [markdown]
# # Autoencoders

# %%
# !pip uninstall datasets

# %%
# !pip install -U datasets
# !pip install datasets==2.7.1
# Out:
# Collecting datasets==2.7.1
#   Using cached datasets-2.7.1-py3-none-any.whl (451 kB)
# Requirement already satisfied: pandas in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets==2.7.1) (1.5.0)
# Requirement already satisfied: dill<0.3.7 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets==2.7.1) (0.3.5.1)
# Requirement already satisfied: aiohttp in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets==2.7.1) (3.8.4)
# Requirement already satisfied: multiprocess in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets==2.7.1) (0.70.13)
# Requirement already satisfied: packaging in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets==2.7.1) (21.3)
# Requirement already satisfied: requests>=2.19.0 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets==2.7.1) (2.28.1)
# Requirement already satisfied: responses<0.19 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets==2.7.1) (0.18.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets==2.7.1) (0.18.0)
# Requirement already satisfied: tqdm>=4.62.1 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets==2.7.1) (4.64.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets==2.7.1) (9.0.0)
# Requirement already satisfied: numpy>=1.17 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets==2.7.1) (1.23.3)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets==2.7.1) (2023.10.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets==2.7.1) (6.0)
# Requirement already satisfied: xxhash in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets==2.7.1) (3.0.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from aiohttp->datasets==2.7.1) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from aiohttp->datasets==2.7.1) (1.3.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from aiohttp->datasets==2.7.1) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from aiohttp->datasets==2.7.1) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from aiohttp->datasets==2.7.1) (22.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from aiohttp->datasets==2.7.1) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from aiohttp->datasets==2.7.1) (1.9.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets==2.7.1) (4.3.0)
# Requirement already satisfied: filelock in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets==2.7.1) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from packaging->datasets==2.7.1) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from requests>=2.19.0->datasets==2.7.1) (2023.7.22)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from requests>=2.19.0->datasets==2.7.1) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from requests>=2.19.0->datasets==2.7.1) (3.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from pandas->datasets==2.7.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from pandas->datasets==2.7.1) (2022.4)
# Requirement already satisfied: six>=1.5 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->datasets==2.7.1) (1.16.0)
# Installing collected packages: datasets
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.14.6
#     Uninstalling datasets-2.14.6:
#       Successfully uninstalled datasets-2.14.6
# Successfully installed datasets-2.7.1

# %%
import pickle,gzip,math,os,time,shutil,torch,matplotlib as mpl,numpy as np,matplotlib.pyplot as plt
import fastcore.all as fc
from collections.abc import Mapping
from pathlib import Path
from operator import attrgetter,itemgetter
from functools import partial

from torch import tensor,nn,optim
from torch.utils.data import DataLoader,default_collate
import torch.nn.functional as F
import torchvision.transforms.functional as TF
from datasets import load_dataset,load_dataset_builder

from fastprogress import progress_bar,master_bar
from miniai.datasets import *
from miniai.training import *
from miniai.conv import *

# %%
from fastcore.test import test_close

torch.set_printoptions(precision=2, linewidth=140, sci_mode=False)
torch.manual_seed(1)
mpl.rcParams['image.cmap'] = 'gray'

import logging
logging.disable(logging.WARNING)

# %% [markdown]
# ## Data

# %% [markdown]
# Now, we switch to the fashion MNIST dataset!

# %%
import datasets

# %%
from datasets import config
print(config.HF_DATASETS_CACHE)
#Check where the cache directory is located
# Out:
# /home/jamesemi/.cache/huggingface/datasets

# %%
# !pip install -U datasets
# Out:
# Requirement already satisfied: datasets in /home/jamesemi/mambaforge/lib/python3.9/site-packages (2.14.6)
# Requirement already satisfied: packaging in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets) (21.3)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets) (2023.10.0)
# Requirement already satisfied: tqdm>=4.62.1 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets) (4.64.0)
# Requirement already satisfied: requests>=2.19.0 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets) (2.28.1)
# Requirement already satisfied: xxhash in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets) (3.0.0)
# Requirement already satisfied: aiohttp in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets) (3.8.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets) (9.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets) (0.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets) (6.0)
# Requirement already satisfied: numpy>=1.17 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets) (1.23.3)
# Requirement already satisfied: pandas in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets) (1.5.0)
# Requirement already satisfied: multiprocess in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from datasets) (0.70.13)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from aiohttp->datasets) (1.9.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: filelock in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (1.26.11)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from pandas->datasets) (2022.4)
# Requirement already satisfied: six>=1.5 in /home/jamesemi/mambaforge/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)

# %%
import os
print(os.getcwd())
# Out:
# /home/jamesemi/git/course22p2/workingnbs/nbs

# %%
x,y = 'image','label'
name = "fashion_mnist"
# dsd = load_dataset(name, ignore_verifications=True)
dsd = load_dataset(name, verification_mode='no_checks')

# %% [markdown]
# Remember, we created the `@inplace` decorator!

# %% [markdown]
# We write a func to transform each image into a tensor:

# %%
@inplace
def transformi(b): b[x] = [TF.to_tensor(o) for o in b[x]]

# %%
bs = 256
tds = dsd.with_transform(transformi)

# %%
tds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 60000
#     })
#     test: Dataset({
#         features: ['image', 'label'],
#         num_rows: 10000
#     })
# })

# %%
ds = tds['train']
img = ds[0]['image']
show_image(img, figsize=(1,1));

# %% [markdown]
# Now we collate the dictionarties using the function we've built already.

# %%
cf = collate_dict(ds)

# %%
def collate_(b): return to_device(cf(b))
def data_loaders(dsd, bs, **kwargs): return {k:DataLoader(v, bs, **kwargs) for k,v in dsd.items()}

# %% [markdown]
# An improved `data_loaders()` function:

# %%
# def collate_(b): return to_device(cf(b))
# def data_loaders(dsd, bs, **kwargs): return {k:DataLoader(v, bs, num_workers = 8, **kwargs) for k,v in dsd.items()}

# %%
dls = data_loaders(tds, bs, collate_fn=collate_)

# %%
dt = dls['train']
dv = dls['test']

xb,yb = next(iter(dt))

# %%
dt = dls['train']
dv = dls['test']

xb,yb = next(iter(dt))

# %% [markdown]
# Using the improved dataloaders with `def data_loaders(dsd, bs, **kwargs): return {k:DataLoader(v, bs, num_workers = 8, **kwargs) for k,v in dsd.items()}`, we get an error. In PyTorch, using multiple processes can start to get complicated. What you definitely can't have your dataloader put things onto the GPU into separate processes. The reason for the error is that we used a collate function to put tings on the function - that is incompatible with using multiple workers. The answer to that problem is that we have to rewrite the fit function entirely. We don't want that. Problem #2? The accuracy we get (86.68%) is not good.

# %% [markdown]
# Pull the labels:

# %%
labels = ds.features[y].names

# %%
labels
# Out:
# ['T - shirt / top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankle boot']

# %%
lbl_getter = itemgetter(*yb[:16])
titles = lbl_getter(labels) #get the titles of everything in the minibatch

# %%
mpl.rcParams['figure.dpi'] = 70
show_images(xb[:16], imsize=1.7, titles=titles)

# %% [markdown]
# There we have it, the Fashion-MNIST minibatch!

# %% [markdown]
# ## Warmup - classify

# %%
from torch import optim

bs = 256
lr = 0.4

# %% [markdown]
# Just using the model from the `07_convolutions.ipynb` notebook:

# %%
cnn = nn.Sequential(
    conv(1, 4),      #14x14
    conv(4, 8),      #7x7
    conv(8, 16),     #4x4
    conv(16, 16),    #2x2
    conv(16,10, act=False),
    nn.Flatten()).to(def_device)

# %%
opt = optim.SGD(cnn.parameters(), lr=lr)
loss,acc = fit(5, cnn, F.cross_entropy, opt, dt, dv)

# %% [markdown]
# You can see here that the model is training VERY slowly. Let's analyze the problem:

# %%
dsd['train'][0]

# %% [markdown]
# With this, we start to see the problem. In MNIST, we had all the data loaded into a single big tensor. But, this HF one is created in a more normal way - where each image is a singlt .png file - without being pre-converted. Why is that a problem? Because - out dataloader is spending all of its time decoding these .png files.

# %% [markdown]
# Run `htop` hen training your model, and you see the CPU usage:
# ![image.png](attachment:9cd3796c-e2ac-438e-a0b8-3baaf18069d3.png)
#
# It's weird that only one CPU is being used - and also, that it is being used to a 100%.

# %% [markdown]
# Now, why does that matter? Run `nvidia-smi dmon -i 0`:
# ![image.png](attachment:f9c27e14-fa64-4a1a-a94f-1187da611c33.png)
# Look at `sm` - symmetric multiprocessor. See how we're only using close to 10% of the GPU? Figure out how to use more GPU compute.

# %% [markdown]
# Also, 86% is really not accurate. How do we know? Go to paperswithcode fashion mnist leaderboard:
# ![image.png](attachment:b1c87535-9305-44a6-a0d3-c543c89032ac.png)
# We're not doing too great with the simple CNN. How do we improve that? We could try a bunch of things - but all of them are going to involve modifying the `fit()` function in complicated ways. Let's put that aside and get on with creating an autoencoder.

# %% [markdown]
# ## Autoencoder

# %%
def deconv(ni, nf, ks=3, act=True):
    layers = [nn.UpsamplingNearest2d(scale_factor=2),
              nn.Conv2d(ni, nf, stride=1, kernel_size=ks, padding=ks//2)]
    if act: layers.append(nn.ReLU())
    return nn.Sequential(*layers)

# %% [markdown]
# `padding=ks//2` is a truncating division that works for any odd sized kernel.

# %% [markdown]
# We've pulled out `eval()` into a separate function:

# %%
def eval(model, loss_func, valid_dl, epoch=0):
    model.eval()
    with torch.no_grad():
        tot_loss,count = 0.,0
        for xb,_ in valid_dl:
            pred = model(xb)
            n = len(xb)
            count += n
            tot_loss += loss_func(pred,xb).item()*n
    print(epoch, f'{tot_loss/count:.3f}')

# %% [markdown]
# Should come back and understand every single line of this!!

# %%
def fit(epochs, model, loss_func, opt, train_dl, valid_dl):
    for epoch in range(epochs):
        model.train()
        for xb,_ in train_dl:
            loss = loss_func(model(xb), xb)
            loss.backward()
            opt.step()
            opt.zero_grad()
        eval(model, loss_func, valid_dl, epoch)

# %% [markdown]
# Notice here that `loss_func` is being applied to `xb` and the output of the model.

# %%
ae = nn.Sequential(   #28x28
    nn.ZeroPad2d(2),  #32x32
    conv(1,2),        #16x16
    conv(2,4),        #8x8
#     conv(4,8),        #4x4
#     deconv(8,4),      #8x8
    deconv(4,2),      #16x16
    deconv(2,1, act=False), #32x32
    nn.ZeroPad2d(-2), #28x28
    nn.Sigmoid()
).to(def_device)

# %%
eval(ae, F.mse_loss, dv)
# Out:
# 0 0.168

# %%
opt = optim.SGD(ae.parameters(), lr=0.01)
fit(5, ae, F.mse_loss, opt, dt, dv)
# Out:
# 0 0.127
# 1 0.119
# 2 0.111
# 3 0.100
# 4 0.083

# %%
opt = optim.SGD(ae.parameters(), lr=0.1)
fit(5, ae, F.mse_loss, opt, dt, dv)
# Out:
# 0 0.033
# 1 0.029
# 2 0.026
# 3 0.025
# 4 0.023

# %%
p = ae(xb)
show_images(p[:16].data.cpu(), imsize=1.5)

# %%
p = ae(xb)
show_images(p[:16].data.cpu(), imsize=1.5)

# %%
show_images(xb[:16].data.cpu(), imsize=1.5)

# %% [markdown]
# But we cannot be working like this - we want to have code setup such that we can iterate fast. For that, we createa learner.
